# %% [markdown]
# 参考文档：https://learnxinyminutes.com/zh-cn/python/

# %%
# 用井字符开头的是单行注释

""" 多行字符串用三个引号
    包裹，也常被用来做多
    行注释
"""
# Out:
# ' 多行字符串用三个引号\n    包裹，也常被用来做多\n    行注释\n'

# %%
from functools import wraps

def beg(target_function):
    @wraps(target_function)
    def wrapper(*args, **kwargs):
        msg, say_please = target_function(*args, **kwargs)
        if say_please:
            return "{} {}".format(msg, "Please!")
        return msg
    return wrapper

@beg
def say(say_please=False):
    msg = "Can I help you?"
    return msg, say_please

print(say())
print(say(say_please=True))
# Out:
# Can I help you?
# Can I help you? Please!

# %%
# Out:
# /Users/ncfxy/Documents/GitHub/ProjectDemos/python/basic
